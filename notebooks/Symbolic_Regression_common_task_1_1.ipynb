# %%
import re
import csv
import os
import pandas as pd

# Function to preprocess equations
def preprocess_equation(equation):
    """Standardizes equation formatting by ensuring consistent spacing and replacing '**' with '^'."""
    equation = equation.replace("**", "^")  # Convert Python-style exponentiation to symbolic representation
    equation = re.sub(r'\s+', '', equation)  # Remove unnecessary whitespace
    return equation

# Function to tokenize equations
def tokenize_equation(equation):
    """Tokenizes the equation into symbols, operators, and functions."""
    functions = ["sin", "cos", "exp", "sqrt", "ln", "arcsin"]
    constants = ["pi", "h", "G", "c", "epsilon", "kB", "T", "m", "q"]
    operators = ["+", "-", "*", "/", "^"]

    token_pattern = r'([a-zA-Z_][a-zA-Z0-9_]*)|([0-9]+\.?[0-9]*)|([\+\-\*/\^()])'

    tokens = []
    for match in re.finditer(token_pattern, equation):
        token = match.group()
        if token in functions:
            tokens.append(f'FUNC_{token.upper()}')
        elif token in constants:
            tokens.append(f'CONST_{token.upper()}')
        elif token in operators:
            tokens.append(f'OP_{token}')
        elif re.match(r'^[0-9]+\.?[0-9]*$', token):
            tokens.append('<NUM>')
        else:
            tokens.append(f'VAR_{token}')

    return tokens

# Load CSV file
file = '/content/FeynmanEquations.csv'
df = pd.read_csv(file)

# Ensure "Formula" column is processed
if "Formula" in df.columns:
    results = []
    for eq in df["Formula"].dropna():
        processed_eq = preprocess_equation(eq)
        tokens = tokenize_equation(processed_eq)
        tokenized_str = " | ".join(tokens)  # Clearly separate tokens

        print(f"Original: {eq}")
        print(f"Tokenized: {tokenized_str}\n")

        results.append({
            "original_equation": eq,
            "processed_equation": processed_eq,
            "tokens": tokenized_str
        })
    # Save results to CSV
    output_csv = "/mnt/data/tokenized_equations.csv"
    # Create the directory if it doesn't exist
    os.makedirs(os.path.dirname(output_csv), exist_ok=True)
    df_output = pd.DataFrame(results)
    df_output.to_csv(output_csv, index=False)
    print(f"Results saved to {output_csv}")
    from google.colab import files
    files.download('/mnt/data/tokenized_equations.csv')
else:
    print("Error: 'Formula' column not found in the CSV file.")
# Out:
# Original: exp(-theta**2/2)/sqrt(2*pi)
# Tokenized: FUNC_EXP | VAR_( | OP_- | VAR_theta | OP_^ | <NUM> | OP_/ | <NUM> | VAR_) | OP_/ | FUNC_SQRT | VAR_( | <NUM> | OP_* | CONST_PI | VAR_)
#
# Original: exp(-(theta/sigma)**2/2)/(sqrt(2*pi)*sigma)
# Tokenized: FUNC_EXP | VAR_( | OP_- | VAR_( | VAR_theta | OP_/ | VAR_sigma | VAR_) | OP_^ | <NUM> | OP_/ | <NUM> | VAR_) | OP_/ | VAR_( | FUNC_SQRT | VAR_( | <NUM> | OP_* | CONST_PI | VAR_) | OP_* | VAR_sigma | VAR_)
#
# Original: exp(-((theta-theta1)/sigma)**2/2)/(sqrt(2*pi)*sigma)
# Tokenized: FUNC_EXP | VAR_( | OP_- | VAR_( | VAR_( | VAR_theta | OP_- | VAR_theta1 | VAR_) | OP_/ | VAR_sigma | VAR_) | OP_^ | <NUM> | OP_/ | <NUM> | VAR_) | OP_/ | VAR_( | FUNC_SQRT | VAR_( | <NUM> | OP_* | CONST_PI | VAR_) | OP_* | VAR_sigma | VAR_)
#
# Original: sqrt((x2-x1)**2+(y2-y1)**2)
# Tokenized: FUNC_SQRT | VAR_( | VAR_( | VAR_x2 | OP_- | VAR_x1 | VAR_) | OP_^ | <NUM> | OP_+ | VAR_( | VAR_y2 | OP_- | VAR_y1 | VAR_) | OP_^ | <NUM> | VAR_)
#
# Original: G*m1*m2/((x2-x1)**2+(y2-y1)**2+(z2-z1)**2)
# Tokenized: CONST_G | OP_* | VAR_m1 | OP_* | VAR_m2 | OP_/ | VAR_( | VAR_( | VAR_x2 | OP_- | VAR_x1 | VAR_) | OP_^ | <NUM> | OP_+ | VAR_( | VAR_y2 | OP_- | VAR_y1 | VAR_) | OP_^ | <NUM> | OP_+ | VAR_( | VAR_z2 | OP_- | VAR_z1 | VAR_) | OP_^ | <NUM> | VAR_)
#
# Original: m_0/sqrt(1-v**2/c**2)
# Tokenized: VAR_m_0 | OP_/ | FUNC_SQRT | VAR_( | <NUM> | OP_- | VAR_v | OP_^ | <NUM> | OP_/ | CONST_C | OP_^ | <NUM> | VAR_)
#
# Original: x1*y1+x2*y2+x3*y3
# Tokenized: VAR_x1 | OP_* | VAR_y1 | OP_+ | VAR_x2 | OP_* | VAR_y2 | OP_+ | VAR_x3 | OP_* | VAR_y3
#
# Original: mu*Nn
# Tokenized: VAR_mu | OP_* | VAR_Nn
#
# Original: q1*q2*r/(4*pi*epsilon*r**3)
# Tokenized: VAR_q1 | OP_* | VAR_q2 | OP_* | VAR_r | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | OP_* | CONST_EPSILON | OP_* | VAR_r | OP_^ | <NUM> | VAR_)
#
# Original: q1*r/(4*pi*epsilon*r**3)
# Tokenized: VAR_q1 | OP_* | VAR_r | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | OP_* | CONST_EPSILON | OP_* | VAR_r | OP_^ | <NUM> | VAR_)
#
# Original: q2*Ef
# Tokenized: VAR_q2 | OP_* | VAR_Ef
#
# Original: q*(Ef+B*v*sin(theta))
# Tokenized: CONST_Q | OP_* | VAR_( | VAR_Ef | OP_+ | VAR_B | OP_* | VAR_v | OP_* | FUNC_SIN | VAR_( | VAR_theta | VAR_) | VAR_)
#
# Original: 1/2*m*(v**2+u**2+w**2)
# Tokenized: <NUM> | OP_/ | <NUM> | OP_* | CONST_M | OP_* | VAR_( | VAR_v | OP_^ | <NUM> | OP_+ | VAR_u | OP_^ | <NUM> | OP_+ | VAR_w | OP_^ | <NUM> | VAR_)
#
# Original: G*m1*m2*(1/r2-1/r1)
# Tokenized: CONST_G | OP_* | VAR_m1 | OP_* | VAR_m2 | OP_* | VAR_( | <NUM> | OP_/ | VAR_r2 | OP_- | <NUM> | OP_/ | VAR_r1 | VAR_)
#
# Original: m*g*z
# Tokenized: CONST_M | OP_* | VAR_g | OP_* | VAR_z
#
# Original: 1/2*k_spring*x**2
# Tokenized: <NUM> | OP_/ | <NUM> | OP_* | VAR_k_spring | OP_* | VAR_x | OP_^ | <NUM>
#
# Original: (x-u*t)/sqrt(1-u**2/c**2)
# Tokenized: VAR_( | VAR_x | OP_- | VAR_u | OP_* | VAR_t | VAR_) | OP_/ | FUNC_SQRT | VAR_( | <NUM> | OP_- | VAR_u | OP_^ | <NUM> | OP_/ | CONST_C | OP_^ | <NUM> | VAR_)
#
# Original: (t-u*x/c**2)/sqrt(1-u**2/c**2)
# Tokenized: VAR_( | VAR_t | OP_- | VAR_u | OP_* | VAR_x | OP_/ | CONST_C | OP_^ | <NUM> | VAR_) | OP_/ | FUNC_SQRT | VAR_( | <NUM> | OP_- | VAR_u | OP_^ | <NUM> | OP_/ | CONST_C | OP_^ | <NUM> | VAR_)
#
# Original: m_0*v/sqrt(1-v**2/c**2)
# Tokenized: VAR_m_0 | OP_* | VAR_v | OP_/ | FUNC_SQRT | VAR_( | <NUM> | OP_- | VAR_v | OP_^ | <NUM> | OP_/ | CONST_C | OP_^ | <NUM> | VAR_)
#
# Original: (u+v)/(1+u*v/c**2)
# Tokenized: VAR_( | VAR_u | OP_+ | VAR_v | VAR_) | OP_/ | VAR_( | <NUM> | OP_+ | VAR_u | OP_* | VAR_v | OP_/ | CONST_C | OP_^ | <NUM> | VAR_)
#
# Original: (m1*r1+m2*r2)/(m1+m2)
# Tokenized: VAR_( | VAR_m1 | OP_* | VAR_r1 | OP_+ | VAR_m2 | OP_* | VAR_r2 | VAR_) | OP_/ | VAR_( | VAR_m1 | OP_+ | VAR_m2 | VAR_)
#
# Original: r*F*sin(theta)
# Tokenized: VAR_r | OP_* | VAR_F | OP_* | FUNC_SIN | VAR_( | VAR_theta | VAR_)
#
# Original: m*r*v*sin(theta)
# Tokenized: CONST_M | OP_* | VAR_r | OP_* | VAR_v | OP_* | FUNC_SIN | VAR_( | VAR_theta | VAR_)
#
# Original: 1/2*m*(omega**2+omega_0**2)*1/2*x**2
# Tokenized: <NUM> | OP_/ | <NUM> | OP_* | CONST_M | OP_* | VAR_( | VAR_omega | OP_^ | <NUM> | OP_+ | VAR_omega_0 | OP_^ | <NUM> | VAR_) | OP_* | <NUM> | OP_/ | <NUM> | OP_* | VAR_x | OP_^ | <NUM>
#
# Original: q/C
# Tokenized: CONST_Q | OP_/ | VAR_C
#
# Original: arcsin(n*sin(theta2))
# Tokenized: FUNC_ARCSIN | VAR_( | VAR_n | OP_* | FUNC_SIN | VAR_( | VAR_theta2 | VAR_) | VAR_)
#
# Original: 1/(1/d1+n/d2)
# Tokenized: <NUM> | OP_/ | VAR_( | <NUM> | OP_/ | VAR_d1 | OP_+ | VAR_n | OP_/ | VAR_d2 | VAR_)
#
# Original: omega/c
# Tokenized: VAR_omega | OP_/ | CONST_C
#
# Original: sqrt(x1**2+x2**2-2*x1*x2*cos(theta1-theta2))
# Tokenized: FUNC_SQRT | VAR_( | VAR_x1 | OP_^ | <NUM> | OP_+ | VAR_x2 | OP_^ | <NUM> | OP_- | <NUM> | OP_* | VAR_x1 | OP_* | VAR_x2 | OP_* | FUNC_COS | VAR_( | VAR_theta1 | OP_- | VAR_theta2 | VAR_) | VAR_)
#
# Original: Int_0*sin(n*theta/2)**2/sin(theta/2)**2
# Tokenized: VAR_Int_0 | OP_* | FUNC_SIN | VAR_( | VAR_n | OP_* | VAR_theta | OP_/ | <NUM> | VAR_) | OP_^ | <NUM> | OP_/ | FUNC_SIN | VAR_( | VAR_theta | OP_/ | <NUM> | VAR_) | OP_^ | <NUM>
#
# Original: arcsin(lambd/(n*d))
# Tokenized: FUNC_ARCSIN | VAR_( | VAR_lambd | OP_/ | VAR_( | VAR_n | OP_* | VAR_d | VAR_) | VAR_)
#
# Original: q**2*a**2/(6*pi*epsilon*c**3)
# Tokenized: CONST_Q | OP_^ | <NUM> | OP_* | VAR_a | OP_^ | <NUM> | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | OP_* | CONST_EPSILON | OP_* | CONST_C | OP_^ | <NUM> | VAR_)
#
# Original: (1/2*epsilon*c*Ef**2)*(8*pi*r**2/3)*(omega**4/(omega**2-omega_0**2)**2)
# Tokenized: VAR_( | <NUM> | OP_/ | <NUM> | OP_* | CONST_EPSILON | OP_* | CONST_C | OP_* | VAR_Ef | OP_^ | <NUM> | VAR_) | OP_* | VAR_( | <NUM> | OP_* | CONST_PI | OP_* | VAR_r | OP_^ | <NUM> | OP_/ | <NUM> | VAR_) | OP_* | VAR_( | VAR_omega | OP_^ | <NUM> | OP_/ | VAR_( | VAR_omega | OP_^ | <NUM> | OP_- | VAR_omega_0 | OP_^ | <NUM> | VAR_) | OP_^ | <NUM> | VAR_)
#
# Original: q*v*B/p
# Tokenized: CONST_Q | OP_* | VAR_v | OP_* | VAR_B | OP_/ | VAR_p
#
# Original: omega_0/(1-v/c)
# Tokenized: VAR_omega_0 | OP_/ | VAR_( | <NUM> | OP_- | VAR_v | OP_/ | CONST_C | VAR_)
#
# Original: (1+v/c)/sqrt(1-v**2/c**2)*omega_0
# Tokenized: VAR_( | <NUM> | OP_+ | VAR_v | OP_/ | CONST_C | VAR_) | OP_/ | FUNC_SQRT | VAR_( | <NUM> | OP_- | VAR_v | OP_^ | <NUM> | OP_/ | CONST_C | OP_^ | <NUM> | VAR_) | OP_* | VAR_omega_0
#
# Original: (h/(2*pi))*omega
# Tokenized: VAR_( | CONST_H | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | VAR_) | VAR_) | OP_* | VAR_omega
#
# Original: I1+I2+2*sqrt(I1*I2)*cos(delta)
# Tokenized: VAR_I1 | OP_+ | VAR_I2 | OP_+ | <NUM> | OP_* | FUNC_SQRT | VAR_( | VAR_I1 | OP_* | VAR_I2 | VAR_) | OP_* | FUNC_COS | VAR_( | VAR_delta | VAR_)
#
# Original: 4*pi*epsilon*(h/(2*pi))**2/(m*q**2)
# Tokenized: <NUM> | OP_* | CONST_PI | OP_* | CONST_EPSILON | OP_* | VAR_( | CONST_H | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | VAR_) | VAR_) | OP_^ | <NUM> | OP_/ | VAR_( | CONST_M | OP_* | CONST_Q | OP_^ | <NUM> | VAR_)
#
# Original: 3/2*pr*V
# Tokenized: <NUM> | OP_/ | <NUM> | OP_* | VAR_pr | OP_* | VAR_V
#
# Original: 1/(gamma-1)*pr*V
# Tokenized: <NUM> | OP_/ | VAR_( | VAR_gamma | OP_- | <NUM> | VAR_) | OP_* | VAR_pr | OP_* | VAR_V
#
# Original: n*kb*T/V
# Tokenized: VAR_n | OP_* | VAR_kb | OP_* | CONST_T | OP_/ | VAR_V
#
# Original: n_0*exp(-m*g*x/(kb*T))
# Tokenized: VAR_n_0 | OP_* | FUNC_EXP | VAR_( | OP_- | CONST_M | OP_* | VAR_g | OP_* | VAR_x | OP_/ | VAR_( | VAR_kb | OP_* | CONST_T | VAR_) | VAR_)
#
# Original: h/(2*pi)*omega**3/(pi**2*c**2*(exp((h/(2*pi))*omega/(kb*T))-1))
# Tokenized: CONST_H | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | VAR_) | OP_* | VAR_omega | OP_^ | <NUM> | OP_/ | VAR_( | CONST_PI | OP_^ | <NUM> | OP_* | CONST_C | OP_^ | <NUM> | OP_* | VAR_( | FUNC_EXP | VAR_( | VAR_( | CONST_H | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | VAR_) | VAR_) | OP_* | VAR_omega | OP_/ | VAR_( | VAR_kb | OP_* | CONST_T | VAR_) | VAR_) | OP_- | <NUM> | VAR_) | VAR_)
#
# Original: mu_drift*q*Volt/d
# Tokenized: VAR_mu_drift | OP_* | CONST_Q | OP_* | VAR_Volt | OP_/ | VAR_d
#
# Original: mob*kb*T
# Tokenized: VAR_mob | OP_* | VAR_kb | OP_* | CONST_T
#
# Original: 1/(gamma-1)*kb*v/A
# Tokenized: <NUM> | OP_/ | VAR_( | VAR_gamma | OP_- | <NUM> | VAR_) | OP_* | VAR_kb | OP_* | VAR_v | OP_/ | VAR_A
#
# Original: n*kb*T*ln(V2/V1)
# Tokenized: VAR_n | OP_* | VAR_kb | OP_* | CONST_T | OP_* | FUNC_LN | VAR_( | VAR_V2 | OP_/ | VAR_V1 | VAR_)
#
# Original: sqrt(gamma*pr/rho)
# Tokenized: FUNC_SQRT | VAR_( | VAR_gamma | OP_* | VAR_pr | OP_/ | VAR_rho | VAR_)
#
# Original: m*c**2/sqrt(1-v**2/c**2)
# Tokenized: CONST_M | OP_* | CONST_C | OP_^ | <NUM> | OP_/ | FUNC_SQRT | VAR_( | <NUM> | OP_- | VAR_v | OP_^ | <NUM> | OP_/ | CONST_C | OP_^ | <NUM> | VAR_)
#
# Original: x1*(cos(omega*t)+alpha*cos(omega*t)**2)
# Tokenized: VAR_x1 | OP_* | VAR_( | FUNC_COS | VAR_( | VAR_omega | OP_* | VAR_t | VAR_) | OP_+ | VAR_alpha | OP_* | FUNC_COS | VAR_( | VAR_omega | OP_* | VAR_t | VAR_) | OP_^ | <NUM> | VAR_)
#
# Original: kappa*(T2-T1)*A/d
# Tokenized: VAR_kappa | OP_* | VAR_( | VAR_T2 | OP_- | VAR_T1 | VAR_) | OP_* | VAR_A | OP_/ | VAR_d
#
# Original: Pwr/(4*pi*r**2)
# Tokenized: VAR_Pwr | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | OP_* | VAR_r | OP_^ | <NUM> | VAR_)
#
# Original: q/(4*pi*epsilon*r)
# Tokenized: CONST_Q | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | OP_* | CONST_EPSILON | OP_* | VAR_r | VAR_)
#
# Original: 1/(4*pi*epsilon)*p_d*cos(theta)/r**2
# Tokenized: <NUM> | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | OP_* | CONST_EPSILON | VAR_) | OP_* | VAR_p_d | OP_* | FUNC_COS | VAR_( | VAR_theta | VAR_) | OP_/ | VAR_r | OP_^ | <NUM>
#
# Original: p_d/(4*pi*epsilon)*3*z/r**5*sqrt(x**2+y**2)
# Tokenized: VAR_p_d | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | OP_* | CONST_EPSILON | VAR_) | OP_* | <NUM> | OP_* | VAR_z | OP_/ | VAR_r | OP_^ | <NUM> | OP_* | FUNC_SQRT | VAR_( | VAR_x | OP_^ | <NUM> | OP_+ | VAR_y | OP_^ | <NUM> | VAR_)
#
# Original: p_d/(4*pi*epsilon)*3*cos(theta)*sin(theta)/r**3
# Tokenized: VAR_p_d | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | OP_* | CONST_EPSILON | VAR_) | OP_* | <NUM> | OP_* | FUNC_COS | VAR_( | VAR_theta | VAR_) | OP_* | FUNC_SIN | VAR_( | VAR_theta | VAR_) | OP_/ | VAR_r | OP_^ | <NUM>
#
# Original: 3/5*q**2/(4*pi*epsilon*d)
# Tokenized: <NUM> | OP_/ | <NUM> | OP_* | CONST_Q | OP_^ | <NUM> | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | OP_* | CONST_EPSILON | OP_* | VAR_d | VAR_)
#
# Original: epsilon*Ef**2/2
# Tokenized: CONST_EPSILON | OP_* | VAR_Ef | OP_^ | <NUM> | OP_/ | <NUM>
#
# Original: sigma_den/epsilon*1/(1+chi)
# Tokenized: VAR_sigma_den | OP_/ | CONST_EPSILON | OP_* | <NUM> | OP_/ | VAR_( | <NUM> | OP_+ | VAR_chi | VAR_)
#
# Original: q*Ef/(m*(omega_0**2-omega**2))
# Tokenized: CONST_Q | OP_* | VAR_Ef | OP_/ | VAR_( | CONST_M | OP_* | VAR_( | VAR_omega_0 | OP_^ | <NUM> | OP_- | VAR_omega | OP_^ | <NUM> | VAR_) | VAR_)
#
# Original: n_0*(1+p_d*Ef*cos(theta)/(kb*T))
# Tokenized: VAR_n_0 | OP_* | VAR_( | <NUM> | OP_+ | VAR_p_d | OP_* | VAR_Ef | OP_* | FUNC_COS | VAR_( | VAR_theta | VAR_) | OP_/ | VAR_( | VAR_kb | OP_* | CONST_T | VAR_) | VAR_)
#
# Original: n_rho*p_d**2*Ef/(3*kb*T)
# Tokenized: VAR_n_rho | OP_* | VAR_p_d | OP_^ | <NUM> | OP_* | VAR_Ef | OP_/ | VAR_( | <NUM> | OP_* | VAR_kb | OP_* | CONST_T | VAR_)
#
# Original: n*alpha/(1-(n*alpha/3))*epsilon*Ef
# Tokenized: VAR_n | OP_* | VAR_alpha | OP_/ | VAR_( | <NUM> | OP_- | VAR_( | VAR_n | OP_* | VAR_alpha | OP_/ | <NUM> | VAR_) | VAR_) | OP_* | CONST_EPSILON | OP_* | VAR_Ef
#
# Original: 1+n*alpha/(1-(n*alpha/3))
# Tokenized: <NUM> | OP_+ | VAR_n | OP_* | VAR_alpha | OP_/ | VAR_( | <NUM> | OP_- | VAR_( | VAR_n | OP_* | VAR_alpha | OP_/ | <NUM> | VAR_) | VAR_)
#
# Original: 1/(4*pi*epsilon*c**2)*2*I/r
# Tokenized: <NUM> | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | OP_* | CONST_EPSILON | OP_* | CONST_C | OP_^ | <NUM> | VAR_) | OP_* | <NUM> | OP_* | VAR_I | OP_/ | VAR_r
#
# Original: rho_c_0/sqrt(1-v**2/c**2)
# Tokenized: VAR_rho_c_0 | OP_/ | FUNC_SQRT | VAR_( | <NUM> | OP_- | VAR_v | OP_^ | <NUM> | OP_/ | CONST_C | OP_^ | <NUM> | VAR_)
#
# Original: rho_c_0*v/sqrt(1-v**2/c**2)
# Tokenized: VAR_rho_c_0 | OP_* | VAR_v | OP_/ | FUNC_SQRT | VAR_( | <NUM> | OP_- | VAR_v | OP_^ | <NUM> | OP_/ | CONST_C | OP_^ | <NUM> | VAR_)
#
# Original: -mom*B*cos(theta)
# Tokenized: OP_- | VAR_mom | OP_* | VAR_B | OP_* | FUNC_COS | VAR_( | VAR_theta | VAR_)
#
# Original: -p_d*Ef*cos(theta)
# Tokenized: OP_- | VAR_p_d | OP_* | VAR_Ef | OP_* | FUNC_COS | VAR_( | VAR_theta | VAR_)
#
# Original: q/(4*pi*epsilon*r*(1-v/c))
# Tokenized: CONST_Q | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | OP_* | CONST_EPSILON | OP_* | VAR_r | OP_* | VAR_( | <NUM> | OP_- | VAR_v | OP_/ | CONST_C | VAR_) | VAR_)
#
# Original: sqrt(omega**2/c**2-pi**2/d**2)
# Tokenized: FUNC_SQRT | VAR_( | VAR_omega | OP_^ | <NUM> | OP_/ | CONST_C | OP_^ | <NUM> | OP_- | CONST_PI | OP_^ | <NUM> | OP_/ | VAR_d | OP_^ | <NUM> | VAR_)
#
# Original: epsilon*c*Ef**2
# Tokenized: CONST_EPSILON | OP_* | CONST_C | OP_* | VAR_Ef | OP_^ | <NUM>
#
# Original: epsilon*Ef**2
# Tokenized: CONST_EPSILON | OP_* | VAR_Ef | OP_^ | <NUM>
#
# Original: q*v/(2*pi*r)
# Tokenized: CONST_Q | OP_* | VAR_v | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | OP_* | VAR_r | VAR_)
#
# Original: q*v*r/2
# Tokenized: CONST_Q | OP_* | VAR_v | OP_* | VAR_r | OP_/ | <NUM>
#
# Original: g_*q*B/(2*m)
# Tokenized: VAR_g_ | OP_* | CONST_Q | OP_* | VAR_B | OP_/ | VAR_( | <NUM> | OP_* | CONST_M | VAR_)
#
# Original: q*h/(4*pi*m)
# Tokenized: CONST_Q | OP_* | CONST_H | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | OP_* | CONST_M | VAR_)
#
# Original: g_*mom*B*Jz/(h/(2*pi))
# Tokenized: VAR_g_ | OP_* | VAR_mom | OP_* | VAR_B | OP_* | VAR_Jz | OP_/ | VAR_( | CONST_H | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | VAR_) | VAR_)
#
# Original: n_0/(exp(mom*B/(kb*T))+exp(-mom*B/(kb*T)))
# Tokenized: VAR_n_0 | OP_/ | VAR_( | FUNC_EXP | VAR_( | VAR_mom | OP_* | VAR_B | OP_/ | VAR_( | VAR_kb | OP_* | CONST_T | VAR_) | VAR_) | OP_+ | FUNC_EXP | VAR_( | OP_- | VAR_mom | OP_* | VAR_B | OP_/ | VAR_( | VAR_kb | OP_* | CONST_T | VAR_) | VAR_) | VAR_)
#
# Original: n_rho*mom*tanh(mom*B/(kb*T))
# Tokenized: VAR_n_rho | OP_* | VAR_mom | OP_* | VAR_tanh | VAR_( | VAR_mom | OP_* | VAR_B | OP_/ | VAR_( | VAR_kb | OP_* | CONST_T | VAR_) | VAR_)
#
# Original: mom*H/(kb*T)+(mom*alpha)/(epsilon*c**2*kb*T)*M
# Tokenized: VAR_mom | OP_* | VAR_H | OP_/ | VAR_( | VAR_kb | OP_* | CONST_T | VAR_) | OP_+ | VAR_( | VAR_mom | OP_* | VAR_alpha | VAR_) | OP_/ | VAR_( | CONST_EPSILON | OP_* | CONST_C | OP_^ | <NUM> | OP_* | VAR_kb | OP_* | CONST_T | VAR_) | OP_* | VAR_M
#
# Original: mom*(1+chi)*B
# Tokenized: VAR_mom | OP_* | VAR_( | <NUM> | OP_+ | VAR_chi | VAR_) | OP_* | VAR_B
#
# Original: Y*A*x/d
# Tokenized: VAR_Y | OP_* | VAR_A | OP_* | VAR_x | OP_/ | VAR_d
#
# Original: Y/(2*(1+sigma))
# Tokenized: VAR_Y | OP_/ | VAR_( | <NUM> | OP_* | VAR_( | <NUM> | OP_+ | VAR_sigma | VAR_) | VAR_)
#
# Original: 1/(exp((h/(2*pi))*omega/(kb*T))-1)
# Tokenized: <NUM> | OP_/ | VAR_( | FUNC_EXP | VAR_( | VAR_( | CONST_H | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | VAR_) | VAR_) | OP_* | VAR_omega | OP_/ | VAR_( | VAR_kb | OP_* | CONST_T | VAR_) | VAR_) | OP_- | <NUM> | VAR_)
#
# Original: (h/(2*pi))*omega/(exp((h/(2*pi))*omega/(kb*T))-1)
# Tokenized: VAR_( | CONST_H | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | VAR_) | VAR_) | OP_* | VAR_omega | OP_/ | VAR_( | FUNC_EXP | VAR_( | VAR_( | CONST_H | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | VAR_) | VAR_) | OP_* | VAR_omega | OP_/ | VAR_( | VAR_kb | OP_* | CONST_T | VAR_) | VAR_) | OP_- | <NUM> | VAR_)
#
# Original: 2*mom*B/(h/(2*pi))
# Tokenized: <NUM> | OP_* | VAR_mom | OP_* | VAR_B | OP_/ | VAR_( | CONST_H | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | VAR_) | VAR_)
#
# Original: sin(E_n*t/(h/(2*pi)))**2
# Tokenized: FUNC_SIN | VAR_( | VAR_E_n | OP_* | VAR_t | OP_/ | VAR_( | CONST_H | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | VAR_) | VAR_) | VAR_) | OP_^ | <NUM>
#
# Original: (p_d*Ef*t/(h/(2*pi)))*sin((omega-omega_0)*t/2)**2/((omega-omega_0)*t/2)**2
# Tokenized: VAR_( | VAR_p_d | OP_* | VAR_Ef | OP_* | VAR_t | OP_/ | VAR_( | CONST_H | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | VAR_) | VAR_) | VAR_) | OP_* | FUNC_SIN | VAR_( | VAR_( | VAR_omega | OP_- | VAR_omega_0 | VAR_) | OP_* | VAR_t | OP_/ | <NUM> | VAR_) | OP_^ | <NUM> | OP_/ | VAR_( | VAR_( | VAR_omega | OP_- | VAR_omega_0 | VAR_) | OP_* | VAR_t | OP_/ | <NUM> | VAR_) | OP_^ | <NUM>
#
# Original: mom*sqrt(Bx**2+By**2+Bz**2)
# Tokenized: VAR_mom | OP_* | FUNC_SQRT | VAR_( | VAR_Bx | OP_^ | <NUM> | OP_+ | VAR_By | OP_^ | <NUM> | OP_+ | VAR_Bz | OP_^ | <NUM> | VAR_)
#
# Original: n*(h/(2*pi))
# Tokenized: VAR_n | OP_* | VAR_( | CONST_H | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | VAR_) | VAR_)
#
# Original: 2*E_n*d**2*k/(h/(2*pi))
# Tokenized: <NUM> | OP_* | VAR_E_n | OP_* | VAR_d | OP_^ | <NUM> | OP_* | VAR_k | OP_/ | VAR_( | CONST_H | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | VAR_) | VAR_)
#
# Original: I_0*(exp(q*Volt/(kb*T))-1)
# Tokenized: VAR_I_0 | OP_* | VAR_( | FUNC_EXP | VAR_( | CONST_Q | OP_* | VAR_Volt | OP_/ | VAR_( | VAR_kb | OP_* | CONST_T | VAR_) | VAR_) | OP_- | <NUM> | VAR_)
#
# Original: 2*U*(1-cos(k*d))
# Tokenized: <NUM> | OP_* | VAR_U | OP_* | VAR_( | <NUM> | OP_- | FUNC_COS | VAR_( | VAR_k | OP_* | VAR_d | VAR_) | VAR_)
#
# Original: (h/(2*pi))**2/(2*E_n*d**2)
# Tokenized: VAR_( | CONST_H | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | VAR_) | VAR_) | OP_^ | <NUM> | OP_/ | VAR_( | <NUM> | OP_* | VAR_E_n | OP_* | VAR_d | OP_^ | <NUM> | VAR_)
#
# Original: 2*pi*alpha/(n*d)
# Tokenized: <NUM> | OP_* | CONST_PI | OP_* | VAR_alpha | OP_/ | VAR_( | VAR_n | OP_* | VAR_d | VAR_)
#
# Original: beta*(1+alpha*cos(theta))
# Tokenized: VAR_beta | OP_* | VAR_( | <NUM> | OP_+ | VAR_alpha | OP_* | FUNC_COS | VAR_( | VAR_theta | VAR_) | VAR_)
#
# Original: -m*q**4/(2*(4*pi*epsilon)**2*(h/(2*pi))**2)*(1/n**2)
# Tokenized: OP_- | CONST_M | OP_* | CONST_Q | OP_^ | <NUM> | OP_/ | VAR_( | <NUM> | OP_* | VAR_( | <NUM> | OP_* | CONST_PI | OP_* | CONST_EPSILON | VAR_) | OP_^ | <NUM> | OP_* | VAR_( | CONST_H | OP_/ | VAR_( | <NUM> | OP_* | CONST_PI | VAR_) | VAR_) | OP_^ | <NUM> | VAR_) | OP_* | VAR_( | <NUM> | OP_/ | VAR_n | OP_^ | <NUM> | VAR_)
#
# Original: -rho_c_0*q*A_vec/m
# Tokenized: OP_- | VAR_rho_c_0 | OP_* | CONST_Q | OP_* | VAR_A_vec | OP_/ | CONST_M
#
# Results saved to /mnt/data/tokenized_equations.csv

# %%
# !ls /mnt/data
# Out:
# tokenized_equations.csv

# %%
from google.colab import files
files.download('/mnt/data/tokenized_equations.csv')
